# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MultiLabelBinarizer
import ast
from itertools import chain

# %%
file_path = '/content/drive/MyDrive/final project sample data/playlist_features.csv'
music = pd.read_csv(file_path)

# %%
music
# Out:
#      Unnamed: 0                Track_id  \
# 0             0  0VjIjW4GlUZAMYd2vXMi3b
# 1             1  7qiZfU4dY1lWllzX7mPBI3
# 2             2  7qEHsqek33rTcFNT9PFqLf
# 3             3  0RiRZpuVRbi7oqRdSMwhQY
# 4             4  7MXVkk9YMctZqd1Srtv4MB
# ..          ...                     ...
# 548         548  1PS1QMdUqOal0ai3Gt7sDQ
# 549         549  1PAgmT6YqGhd6zT9kN9gIo
# 550         550  0gzqZ9d1jIKo9psEIthwXe
# 551         551  2P9lGiFMjKT6CGKVAjWia4
# 552         552  0eqH0ALoDQevq59YcQ53KE
#
#                                               Name  \
# 0                                  Blinding Lights
# 1                                     Shape of You
# 2                                Someone You Loved
# 3    Sunflower - Spider-Man: Into the Spider-Verse
# 4                                          Starboy
# ..                                             ...
# 548                                    Gold Digger
# 549                                           Hero
# 550                                  Beautiful Day
# 551                                The Right Thing
# 552                                 Hollaback Girl
#
#                                        Album            Artist Release_Date  \
# 0                                After Hours        The Weeknd   2020-03-20
# 1                                 ÷ (Deluxe)        Ed Sheeran   2017-03-03
# 2    Divinely Uninspired To A Hellish Extent     Lewis Capaldi   2019-05-17
# 3                       Hollywood's Bleeding       Post Malone   2019-09-06
# 4                                    Starboy        The Weeknd   2016-11-25
# ..                                       ...               ...          ...
# 548                        Late Registration        Kanye West   2005-08-30
# 549                                   Escape  Enrique Iglesias   2001-01-01
# 550          All That You Can't Leave Behind                U2   2000-01-01
# 551                          The Right Thing        AVAN HAVEN   2022-06-27
# 552                    Love Angel Music Baby      Gwen Stefani   2004-11-22
#
#      Length  Popularity  Acousticness  Danceability  Energy  Instrumentness  \
# 0    200040          93       0.00146         0.514   0.730        0.000095
# 1    233712          89       0.58100         0.825   0.652        0.000000
# 2    182160          92       0.75100         0.501   0.405        0.000000
# 3    157560          88       0.53300         0.755   0.522        0.000000
# 4    230453          94       0.14100         0.679   0.587        0.000006
# ..      ...         ...           ...           ...     ...             ...
# 548  207626          85       0.01950         0.629   0.696        0.000000
# 549  264240          72       0.13600         0.346   0.641        0.000008
# 550  248400          78       0.01540         0.536   0.928        0.001340
# 551  127090          13       0.50800         0.780   0.525        0.000000
# 552  199853          75       0.35000         0.926   0.916        0.000006
#
#      Liveness  Loudness  Valence  Speechness    Tempo  Time_Signature
# 0      0.0897    -5.934    0.334      0.0598  171.005               4
# 1      0.0931    -3.183    0.931      0.0802   95.977               4
# 2      0.1050    -5.679    0.446      0.0319  109.891               4
# 3      0.0685    -4.368    0.925      0.0575   89.960               4
# 4      0.1370    -7.015    0.486      0.2760  186.003               4
# ..        ...       ...      ...         ...      ...             ...
# 548    0.0554    -5.572    0.623      0.3480   93.034               4
# 549    0.1080    -5.627    0.159      0.0504   77.281               4
# 550    0.2000    -6.492    0.389      0.0589  136.258               4
# 551    0.1760    -8.358    0.563      0.0334  139.971               4
# 552    0.0234    -2.221    0.904      0.0929  110.007               4
#
# [553 rows x 18 columns]
