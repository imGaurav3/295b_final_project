# %%
import pandas as pd

# Sample data
d1 = {
    'id': [1, 2, 3],
    'happy_movie': [['Drama', 'Comedy'], ['Romance', 'Family'], ['Adventure']],
    'sad_movie': [['Drama', 'Thriller'], ['Crime'], ['Horror', 'Science Fiction']],
    'neutral_movie': [['Comedy'], ['Action', 'Adventure'], ['Crime']],
    'fav_movie': ['The Godfather', "Schindler's List", 'The Shawshank Redemption']
}

# Creating DataFrame
user = pd.DataFrame(d1)

# Display the DataFrame
print(user)
# Out:
#    id        happy_movie                  sad_movie        neutral_movie  \
# 0   1    [Drama, Comedy]          [Drama, Thriller]             [Comedy]
# 1   2  [Romance, Family]                    [Crime]  [Action, Adventure]
# 2   3        [Adventure]  [Horror, Science Fiction]              [Crime]
#
#                   fav_movie
# 0             The Godfather
# 1          Schindler's List
# 2  The Shawshank Redemption

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             3 non-null      int64
#  1   happy_movie    3 non-null      object
#  2   sad_movie      3 non-null      object
#  3   neutral_movie  3 non-null      object
#  4   fav_movie      3 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 248.0+ bytes

# %%
file_path = '/content/drive/MyDrive/final project sample data/10000 Movies Data'
minfo = pd.read_csv(file_path)
minfo.head()
# Out:
#    Unnamed: 0  Movie_id                        title  \
# 0           0       238                The Godfather
# 1           1       278     The Shawshank Redemption
# 2           2       240        The Godfather Part II
# 3           3     19404  Dilwale Dulhania Le Jayenge
# 4           4       424             Schindler's List
#
#                                               Genres release_date  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...   1972-03-14
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...   1994-09-23
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...   1974-12-20
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   1995-10-19
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...   1993-12-15
#
#                                             Keywords  \
# 0  [{'id': 131, 'name': 'italy'}, {'id': 697, 'na...
# 1  [{'id': 378, 'name': 'prison'}, {'id': 417, 'n...
# 2  [{'id': 131, 'name': 'italy'}, {'id': 700, 'na...
# ...

# %%
# Assuming 'df' is your original DataFrame
movie1 = minfo[['Movie_id', 'title', 'Genres', 'popularity', 'vote_average', 'vote_count']]

# Display the extracted columns
movie1.head()
# Out:
#    Movie_id                        title  \
# 0       238                The Godfather
# 1       278     The Shawshank Redemption
# 2       240        The Godfather Part II
# 3     19404  Dilwale Dulhania Le Jayenge
# 4       424             Schindler's List
#
#                                               Genres  popularity  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      93.552
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      78.664
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      55.752
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      22.150
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...      53.542
#
#    vote_average  vote_count
# 0           8.7       16814
# 1           8.7       22542
# 2           8.6       10187
# 3           8.6        3927
# 4           8.6       13382

# %%
movie1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9980 entries, 0 to 9979
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie_id      9980 non-null   int64
#  1   title         9980 non-null   object
#  2   Genres        9980 non-null   object
#  3   popularity    9980 non-null   float64
#  4   vote_average  9980 non-null   float64
#  5   vote_count    9980 non-null   int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 467.9+ KB

# %%
# Sample data with ratings on a scale from 1 to 10
data = {
    'userid': [1, 2, 3, 1, 2],
    'movieid': [238, 278, 240, 19404, 424],
    'rating_given': [8.0, 5.5, 9.5, 7.0, 6.5],
    'watching_mood': ['Happy', 'Sad', 'Neutral', 'Happy', 'Neutral']
}

# Creating DataFrame
watched = pd.DataFrame(data)

# Display the DataFrame
watched.head()
# Out:
#    userid  movieid  rating_given watching_mood
# 0       1      238           8.0         Happy
# 1       2      278           5.5           Sad
# 2       3      240           9.5       Neutral
# 3       1    19404           7.0         Happy
# 4       2      424           6.5       Neutral

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Flatten, Dense, Dropout, concatenate
from tensorflow.keras.optimizers import Adam

# %%
def extract_genres(genres_str):
    genres = [g['name'] for g in eval(genres_str)]
    return genres

# %%
movie = movie1.copy()
movie['Genres'] = movie['Genres'].apply(extract_genres)

# %%
print(movie)
# Out:
#       Movie_id                          title                      Genres  \
# 0          238                  The Godfather              [Drama, Crime]
# 1          278       The Shawshank Redemption              [Drama, Crime]
# 2          240          The Godfather Part II              [Drama, Crime]
# 3        19404    Dilwale Dulhania Le Jayenge    [Comedy, Drama, Romance]
# 4          424               Schindler's List       [Drama, History, War]
# ...        ...                            ...                         ...
# 9975    384737                 Precious Cargo   [Action, Crime, Thriller]
# 9976    282813                    The Pyramid                    [Horror]
# 9977    134375  Home Alone: The Holiday Heist  [Comedy, Family, TV Movie]
# 9978     10477                         Driven                    [Action]
# 9979    243688                    Poltergeist                    [Horror]
#
#       popularity  vote_average  vote_count
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
movie[['popularity', 'vote_average', 'vote_count']] = scaler.fit_transform(movie[['popularity', 'vote_average', 'vote_count']])

# %%
print(movie)
# Out:
#       Movie_id                          title                      Genres  \
# 0          238                  The Godfather              [Drama, Crime]
# 1          278       The Shawshank Redemption              [Drama, Crime]
# 2          240          The Godfather Part II              [Drama, Crime]
# 3        19404    Dilwale Dulhania Le Jayenge    [Comedy, Drama, Romance]
# 4          424               Schindler's List       [Drama, History, War]
# ...        ...                            ...                         ...
# 9975    384737                 Precious Cargo   [Action, Crime, Thriller]
# 9976    282813                    The Pyramid                    [Horror]
# 9977    134375  Home Alone: The Holiday Heist  [Comedy, Family, TV Movie]
# 9978     10477                         Driven                    [Action]
# 9979    243688                    Poltergeist                    [Horror]
#
#       popularity  vote_average  vote_count
# ...

# %%
mlb = MultiLabelBinarizer()
movie_genres = mlb.fit_transform(movie['Genres'])

# %%
# Assuming 'movie_genres' is the binary encoded matrix from the MultiLabelBinarizer
# and 'movie' DataFrame contains a 'Movie_id' column

# Update the creation of movie_genres_df to set Movie_id as the index
movie_genres_df = pd.DataFrame(movie_genres, columns=mlb.classes_, index=movie['Movie_id'])

# %%
movie_genres_df
# Out:
#           Action  Adventure  Animation  Comedy  Crime  Drama  Family  Fantasy  \
# Movie_id
# 238            0          0          0       0      1      1       0        0
# 278            0          0          0       0      1      1       0        0
# 240            0          0          0       0      1      1       0        0
# 19404          0          0          0       1      0      1       0        0
# 424            0          0          0       0      0      1       0        0
# ...          ...        ...        ...     ...    ...    ...     ...      ...
# 384737         1          0          0       0      1      0       0        0
# 282813         0          0          0       0      0      0       0        0
# 134375         0          0          0       1      0      0       1        0
# 10477          1          0          0       0      0      0       0        0
# 243688         0          0          0       0      0      0       0        0
#
# ...

# %%
def build_model(num_users, num_movies, num_genres):
    # User Input
    user_input = Input(shape=(1,), name='user_input')
    user_embedding = Embedding(num_users, 8, name='user_embedding')(user_input)
    user_vec = Flatten(name='user_flatten')(user_embedding)

    # Movie Input
    movie_input = Input(shape=(1,), name='movie_input')
    movie_embedding = Embedding(num_movies, 8, name='movie_embedding')(movie_input)
    movie_vec = Flatten(name='movie_flatten')(movie_embedding)

    # Genres Input
    genres_input = Input(shape=(num_genres,), name='genres_input')

    # Concatenate Features
    concat = concatenate([user_vec, movie_vec, genres_input], axis=-1)

    # Dense Layers
    dense = Dense(128, activation='relu')(concat)
    dropout = Dropout(0.5)(dense)
    output = Dense(1, activation='linear')(dropout)

    model = Model(inputs=[user_input, movie_input, genres_input], outputs=output)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
num_users = user['id'].nunique()
print(num_users)
# Out:
# 3

# %%
num_movies = movie['Movie_id'].nunique()
print(num_movies)
# Out:
# 9980

# %%
num_genres = len(mlb.classes_)
print(num_genres)
# Out:
# 18

# %%
model = build_model(num_users, num_movies, num_genres)

# %%
# First, ensure the mood-related columns in the 'user' DataFrame are accessible for merging.
# Assuming 'happy_movie', 'sad_movie', etc., are already correctly formatted as lists in the 'user' DataFrame.

# Next, create a function to map mood to user's genre preferences.
def map_user_preferences(row):
    user_id = row['userid']
    mood = row['watching_mood']
    user_row = user[user['id'] == user_id].iloc[0]  # Fetch the user row based on userid
    if mood == 'Happy':
        return user_row['happy_movie']
    elif mood == 'Sad':
        return user_row['sad_movie']
    elif mood == 'Neutral':
        return user_row['neutral_movie']
    else:
        return []  # Return an empty list or a default value if mood doesn't match

# Apply this function to the 'watched' DataFrame to create a new column with preferred genres.
watched['preferred_genres'] = watched.apply(map_user_preferences, axis=1)

# %%
print(watched)
# Out:
#    userid  movieid  rating_given watching_mood     preferred_genres
# 0       1      238           8.0         Happy      [Drama, Comedy]
# 1       2      278           5.5           Sad              [Crime]
# 2       3      240           9.5       Neutral              [Crime]
# 3       1    19404           7.0         Happy      [Drama, Comedy]
# 4       2      424           6.5       Neutral  [Action, Adventure]

# %%
# Ensure 'Movie_id' in 'movie' DataFrame is the correct data type for merging.
movie['Movie_id'] = movie['Movie_id'].astype(int)

# Merge 'watched' with 'movie' based on 'movieid' and 'Movie_id'.
merged_df = pd.merge(watched, movie, left_on='movieid', right_on='Movie_id')

# At this point, 'merged_df' contains user watching history, mood-based genre preferences,
# and detailed movie information, including normalized features and binary-encoded genres.

# %%
print(merged_df)
# Out:
#    userid  movieid  rating_given watching_mood     preferred_genres  Movie_id  \
# 0       1      238           8.0         Happy      [Drama, Comedy]       238
# 1       2      278           5.5           Sad              [Crime]       278
# 2       3      240           9.5       Neutral              [Crime]       240
# 3       1    19404           7.0         Happy      [Drama, Comedy]     19404
# 4       2      424           6.5       Neutral  [Action, Adventure]       424
#
#                          title                    Genres  popularity  \
# 0                The Godfather            [Drama, Crime]    0.023897
# 1     The Shawshank Redemption            [Drama, Crime]    0.020069
# 2        The Godfather Part II            [Drama, Crime]    0.014179
# 3  Dilwale Dulhania Le Jayenge  [Comedy, Drama, Romance]    0.005540
# 4             Schindler's List     [Drama, History, War]    0.013611
#
#    vote_average  vote_count
# 0      0.729167    0.517404
# ...

# %%
# Assuming user IDs and movie IDs are already encoded as integers in `merged_df`
user_ids = merged_df['userid'].values.reshape(-1, 1)  # Reshape for the model
movie_ids = merged_df['movieid'].values.reshape(-1, 1)  # Reshape for the model

# For genres, use the binary encoded genres directly from the movies
# Note: Ensure `movie_genres_df` indexing aligns with `merged_df['Movie_id']`
genres_input = np.stack(movie_genres_df.loc[merged_df['Movie_id']].values)

# Ratings as labels
ratings = merged_df['rating_given'].values

# %%
history = model.fit([user_ids, movie_ids, genres_input], ratings,
                    epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-89-0ff260ae4337> in <cell line: 1>()
# ----> 1 history = model.fit([user_ids, movie_ids, genres_input], ratings,
#       2                     epochs=10, batch_size=32)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ...

# %%
user_embedding = Embedding(input_dim=num_users, output_dim=embedding_size, name='user_embedding')
movie_embedding = Embedding(input_dim=num_movies, output_dim=embedding_size, name='movie_embedding')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-2c7b16d170cf> in <cell line: 1>()
# ----> 1 user_embedding = Embedding(input_dim=num_users, output_dim=embedding_size, name='user_embedding')
#       2 movie_embedding = Embedding(input_dim=num_movies, output_dim=embedding_size, name='movie_embedding')
#
# NameError: name 'embedding_size' is not defined
